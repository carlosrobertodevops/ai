# %% [markdown]
# # **Descrição do projeto de machine learning**
# Antes de escrever qualquer código, precisamos entender o problema que queremos resolver e fazer uma descrição eficiente do projeto, visando a comunicação simples e rápida do objetivo do projeto para técnicos, gestores e colaboradores.
#
# ### **1 - Descrição do problema ou tarefa:**
# Predições de possíveis locais de Crimes baseados nos dados de CVLIs do NEAC
#
# ### **2 - Descrição da solução de IA:**
# Treinamento supervisionado de modelo de regressão para predição com base nos dados das dimensões dos locais e tipo criminal que está relacionado com as CVLIs, com base em 7 atributos (características).
# São alguns locais possíveis: Via Pública, Imediações de Casa, Próximo de Casa, Porta de Casa, Dentro de Casa, Presídio, Residência, Vegetação, Bar, Estabelecimento Comercial, entre outros …
#
# ### **3 - Fonte de dados: (mudanças aqui)**
#
# Dados do NEAC/SSPAL (Núcleo de Estatística e Análise Criminais)
#
# - NEAC_CVLI_2023.csv - base de validação
# https://drive.google.com/file/d/1L7fHdQ5NSE8l22NV8xy-w4hHV9xMRktg/view?usp=sharing
#
# - NEAC_CVLI_2022.csv - base de testes
# https://drive.google.com/file/d/1l1WlIaNth_9il2OGCzWcCc1KrRyjM19r/view?usp=sharing
#
# - NEAC_CVLI.csv - Dados - base de treinamento (2012 ate 2022)
# https://drive.google.com/file/d/1pMOhYHnam6pCs8tt4yLMQDZGX_anK4LV/view?usp=sharing
#
# ### **4 - Variáveis independentes (preditoras ou "features"):**
#
# - Tipo ciminal - SUBJETIVIDADE_COMPLEMANTAR (str)
# - Instrumento - INSTRUMENTO (str)
# - Data do Fato - DATA_HORA_FATO (DateTime)
# - Turno do Fato - TURNO (str)
# - Cor ou Raça da Vítima - COR_RACA_VITIMA (str)
# - Sexo da Vítima - SEXO_VITIMA (str)
# - Dia da Semana - DIA_SEMANA (num)
#
# ### **5 - Variável dependente (resposta ou "target"):**
#
# Local do Fato - LOCAL_FATO (str)
#
# ### **6- Base de dados/estrutura de dados:**
#
# |#|Description| Field|Non-Null Count| Data type|X ou y|Drop
# |-|-----------|:-----|:---------|:--------|:-------|:---|
# | 0 ||Unnamed: 0|63 non-null|int64|-|*|
# | 1 ||created_on|63 non-null|object|-|*|
# | 2 ||operation|63 non-null|object|-|*|
# | 3 ||property_type|63 non-null|object|-|*|
# | 4 ||place_name|63 non-null|object|-|*|
# | 5 ||place_with_parent_names|63 non-null|object|-|*|
# | 6 ||geonames_id|0 non-null|float64|-|*|
# | 7 ||lat_lon|41 non-null|object|-|*|
# | 8 ||lat|41 non-null|float64|-|*|
# | 9 ||lon|41 non-null|float64|-|*|
# | 10 ||price|63 non-null|float64|y|*|
# | 11 ||currency|63 non-null|object|-|*|
# | 12 ||price_aprox_local_currency|63 non-null|float64|X|*|
# | 13 ||price_aprox_usd|63 non-null|float64|X||
# | 14 ||surface_total_in_m2|16 non-null|float64|X|*|
# | 15 ||surface_covered_in_m2|57 non-null|float64|X|*|
# | 16 ||price_usd_per_m2|56 non-null|float64|X||
# | 17 ||price_per_m2|56 non-null|float64|X||
# | 18 ||floor|7 non-null|float64|X||
# | 19 ||rooms|22 non-null|float64|X||
# | 20 ||expenses|11 non-null|float64|-|*||
# | 21 ||properati_url|63 non-null|object|-|*|
# | 22 ||description|63 non-null|object|-|*|
# | 24 ||image_thumbnail|63 non-null|object|-|*|
# | 25 ||location|41 non-null|object|-|*|

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'c:\\Users\\carlo\\Documentos\\Projetos\\esmpu\\ia\\ml\\chegei'

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/bootcamp/dados'

# %%
# %pwd
# Out:
# 'c:\\Users\\carlo\\Documentos\\Projetos\\esmpu\\ia\\ml\\chegei'

# %%
# %ls -a
# Out:
#  O volume na unidade C � Local Disk
#  O N�mero de S�rie do Volume � 987E-FA28
#
#  Pasta de c:\Users\carlo\Documentos\Projetos\esmpu\ia\ml\chegei
# Arquivo nao encontrado

# %%
df = pd.read_csv('./dados/NEAC_CVLI_2022.csv',index_col=0)
df.to_csv('./dados/NEAC_CVLI_2022_bkp.csv')

# %%
df.head()
# Out:
#              ID      NIC SUBJETIVIDADE SUBJETIVIDADE_COMPLEMENTAR  \
# OBJECTID
# 28893     47087  44514.0          CVLI                  Homicídio
# 28873     47088  42028.0          CVLI                Feminicídio
# 34938     47173  44659.0          CVLI                  Homicídio
# 28895     47089  42066.0          CVLI                  Homicídio
# 28896     47092  32703.0          CVLI                  Homicídio
#
#          INSTRUMENTO_UTILIZADO       DATA_HORA_FATO  ANO_FATO  MES_FATO  \
# OBJECTID
# 28893                       NI  01/01/2022 04:22:00      2022         1
# 28873                   BRANCA  01/01/2022 05:30:00      2022         1
# 34938                      PAF  01/01/2022 06:00:00      2022         1
# 28895                      PAF  01/01/2022 08:00:00      2022         1
# 28896             ESPANCAMENTO  01/01/2022 14:22:00      2022         1
#
#          MES_FATO_TEXTO  DIA_FATO  ... SEXO_VITIMA  OCUPACAO_VITIMA  \
# OBJECTID                           ...
# 28893               Jan         1  ...   Masculino              NaN
# 28873               Jan         1  ...    Feminino              NaN
# 34938               Jan         1  ...   Masculino              NaN
# 28895               Jan         1  ...   Masculino              NaN
# 28896               Jan         1  ...   Masculino              NaN
#
#          ESCOLARIDADE_VITIMA ESTADO_CIVIL_VITIMA AFINIDADE_AGRESSOR  \
# OBJECTID
# 28893                    NaN            Solteiro                NaN
# 28873                    NaN                 NaN             Amante
# 34938                    NaN            Solteiro                NaN
# 28895                    NaN            Solteiro                NaN
# 28896                    NaN                 NaN                NaN
#
#                                                   LINK_SITE SITUACAO_ESPECIAL  \
# OBJECTID
# 28893                                                   NaN               NaN
# 28873     https://alagoasweb.com/preso-principal-suspeit...               NaN
# 34938                                                   NaN               NaN
# 28895     https://correionoticia.com.br/noticia/policia/...               NaN
# 28896                                                   NaN               NaN
#
#                     LONGITUDE            LATITUDE DIA_SEMANA_FATO_NUM
# OBJECTID
# 28893     -36,098669000000001  -9,792465999999999                 7.0
# 28873     -36,397399999999998  -9,951919999999999                 7.0
# 34938     -37,286791000000001  -9,540119000000001                 7.0
# 28895     -38,001280999999999  -9,390290999999999                 7.0
# 28896     -35,723140000000001            -9,54997                 7.0
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (857, 35)

# %%
df = pd.read_csv('./dados/NEAC_CVLI.csv',index_col=0)

# %%
df.head()
# Out:
#           ID  NIC SUBJETIVIDADE SUBJETIVIDADE_COMPLEMENTAR  \
# OBJECTID
# 14        26  NaN          CVLI                  Homicídio
# 498       27  NaN          CVLI                  Homicídio
# 137       28  NaN          CVLI                  Homicídio
# 380       30  NaN          CVLI                  Homicídio
# 429       29  NaN          CVLI                  Homicídio
#
#          INSTRUMENTO_UTILIZADO     DATA_HORA_FATO  ANO_FATO  MES_FATO  \
# OBJECTID
# 14                ESPANCAMENTO  1/1/2012 01:00:00      2012         1
# 498                     BRANCA  1/1/2012 02:45:00      2012         1
# 137                        PAF  1/1/2012 03:00:00      2012         1
# 380                        PAF  1/1/2012 05:00:00      2012         1
# 429                        PAF  1/1/2012 05:00:00      2012         1
#
#          MES_FATO_TEXTO  DIA_FATO  ... OCUPACAO_VITIMA  ESCOLARIDADE_VITIMA  \
# OBJECTID                           ...
# 14                  Jan         1  ...      Agricultor         Alfabetizado
# 498                 Jan         1  ...       Estudante          Fundamental
# 137                 Jan         1  ...     Comerciante                Médio
# 380                 Jan         1  ...      Agricultor          Fundamental
# 429                 Jan         1  ...      Agricultor         Alfabetizado
#
#          ESTADO_CIVIL_VITIMA AFINIDADE_AGRESSOR  \
# OBJECTID
# 14                    Casado                NaN
# 498                 Solteiro                NaN
# 137                 Solteiro                NaN
# 380                   Casado                NaN
# 429                   Casado                NaN
#
#                                                   LINK_SITE SITUACAO_ESPECIAL  \
# OBJECTID
# 14                                                      NaN               NaN
# 498                                                     NaN               NaN
# 137       http://g1.globo.com/al/alagoas/noticia/2016/11...               NaN
# 380                                                     NaN               NaN
# 429                                                     NaN               NaN
#
#           LONGITUDE  LATITUDE  \
# OBJECTID
# 14       -37.353172 -9.164467
# 498      -35.403900 -9.045000
# 137      -36.238403 -9.363369
# 380      -37.192840 -9.517126
# 429      -37.192840 -9.517126
#
#                                                     FORMATO  \
# OBJECTID
# 14        "SDE"."ST_GEOMETRY"(1,1,-37.353172,-9.164467,-...
# 498       "SDE"."ST_GEOMETRY"(1,1,-35.4039,-9.0450000000...
# 137       "SDE"."ST_GEOMETRY"(1,1,-36.238403,-9.36336899...
# 380       "SDE"."ST_GEOMETRY"(1,1,-37.19284,-9.517126000...
# 429       "SDE"."ST_GEOMETRY"(1,1,-37.19284,-9.517126000...
#
#          DIA_SEMANA_FATO_NUM
# OBJECTID
# 14                         1
# 498                        1
# 137                        1
# 380                        1
# 429                        1
#
# [5 rows x 36 columns]

# %%
df.dtypes
# Out:
# ID                              int64
# NIC                           float64
# SUBJETIVIDADE                  object
# SUBJETIVIDADE_COMPLEMENTAR     object
# INSTRUMENTO_UTILIZADO          object
# DATA_HORA_FATO                 object
# ANO_FATO                        int64
# MES_FATO                        int64
# MES_FATO_TEXTO                 object
# DIA_FATO                        int64
# DIA_SEMANA_FATO                object
# HORA_FATO                       int64
# TURNO                          object
# CIDADE_FATO                    object
# BAIRRO_FATO                    object
# RISP                           object
# AISP                           object
# ENDERECO_FATO                  object
# PT_REF_FATO                    object
# LOCAL_FATO                     object
# NOME_VITIMA                    object
# ALCUNHA_VITIMA                 object
# MAE_VITIMA                     object
# IDADE_VITIMA                  float64
# COR_RACA_VITIMA                object
# SEXO_VITIMA                    object
# OCUPACAO_VITIMA                object
# ESCOLARIDADE_VITIMA            object
# ESTADO_CIVIL_VITIMA            object
# AFINIDADE_AGRESSOR             object
# LINK_SITE                      object
# SITUACAO_ESPECIAL              object
# LONGITUDE                      object
# LATITUDE                       object
# DIA_SEMANA_FATO_NUM           float64
# dtype: object

# %%
df.shape
# Out:
# (857, 35)

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1l1WlIaNth_9il2OGCzWcCc1KrRyjM19r' -O NEAC_CVLI_2022_2.csv

# %%
#!wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1l1WlIaNth_9il2OGCzWcCc1KrRyjM19r' -O NEAC_CVLI_2022_2.csv

# %%
# %ls
# Out:
#  O volume na unidade C � Local Disk
#  O N�mero de S�rie do Volume � 987E-FA28
#
#  Pasta de c:\Users\carlo\Documentos\Projetos\esmpu\ia\ml\chegei
#
# 22/06/2023  08:48    <DIR>          .
# 22/06/2023  08:49    <DIR>          ..
# 26/05/2023  15:28                 7 .gitignore
# 17/06/2023  18:24               539 campos-colunas-cvli.txt
# 22/06/2023  08:52    <DIR>          dados
# 26/05/2023  15:28               953 pf-chegei-cvli.md
# 26/05/2023  15:28            99.484 pipel_mixto_cvli.ipynb
# 22/06/2023  08:55            31.299 projeto-ml-cvli.ipynb
# 17/06/2023  18:31             3.352 projeto-ml-cvli.md
# 26/05/2023  15:28            22.628 proj-ml-cvli.ipynb
#                7 arquivo(s)        158.262 bytes
#                3 pasta(s)   399.184.338.944 bytes dispon�veis
