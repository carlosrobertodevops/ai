# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Gráfico de dispersão com seaborn

# %%
# Importação das bibliotecas
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
# Carregamento da base de dados
base = pd.read_csv("../dados/co2.csv")
base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
# Gráfico de dispersão utilizando os atributos conc e uptake, agrupamento pelo type
import matplotlib.pyplot as plt

srn.scatterplot(data=base, x=base.conc, y=base.uptake, hue=base.Type)
plt.show()

# %%
# Seleção de registros específicos da base de dados (Quebec e Mississipi)
q = base.loc[base["Type"] == "Quebec"]
m = base.loc[base["Type"] == "Mississippi"]

# %%
# Subgráfico (1 linha e duas colunas) mostrando gráficos sobre cada região
plt.figure()
plt.subplot(1, 2, 1)
srn.scatterplot(data=q, x=q.conc, y=q.uptake).set_title("Quebec")
plt.subplot(1, 2, 2)
srn.scatterplot(data=q, x=q.conc, y=q.uptake).set_title("Mississippi")
plt.tight_layout()
plt.show()

# %%
# Refrigerado e não refrigerado
ch = base.loc[base["Treatment"] == "chilled"]
nc = base.loc[base["Treatment"] == "nonchilled"]

# %%
# Gráfico somente com 'chilled' e 'nonchilled'
plt.figure()
plt.subplot(1, 2, 1)
srn.scatterplot(data=ch, x=ch.conc, y=ch.uptake).set_title("Chilled")
plt.subplot(1, 2, 2)
srn.scatterplot(data=nc, x=nc.conc, y=nc.uptake).set_title("Non chilled")
plt.tight_layout()
plt.show()

# %%
# Carregamento de outro arquivo, cancer de esofago
base2 = pd.read_csv("../dados/esoph.csv")
base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# cor padrao da srn
colorpalette = srn.color_palette()

# Gráfico entre os atributos 'alcgp' e 'ncontrols'
srn.catplot(x="alcgp", y="ncontrols", data=base2, jitter=False, palette=colorpalette)
plt.show()
# Out:
# /var/folders/jh/6dgbv5ys7yld3jn9g3n942s40000gn/T/ipykernel_15517/3527294986.py:5: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   srn.catplot(x="alcgp", y="ncontrols", data=base2, jitter=False, palette=colorpalette)
# /var/folders/jh/6dgbv5ys7yld3jn9g3n942s40000gn/T/ipykernel_15517/3527294986.py:5: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   srn.catplot(x="alcgp", y="ncontrols", data=base2, jitter=False, palette=colorpalette)

# %%
# Gráfico entre os atributos 'alcgp' e 'ncontrols', com agrupamento
# pcolor = srn.color_palette("Spectral")
srn.catplot(
    x="alcgp", y="ncontrols", data=base2, col="tobgp", palette=colorpalette
)  # palette = ['blue', 'red', 'green', 'yellow'])
# Out:
# /var/folders/jh/6dgbv5ys7yld3jn9g3n942s40000gn/T/ipykernel_15517/53993724.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   srn.catplot(
# /var/folders/jh/6dgbv5ys7yld3jn9g3n942s40000gn/T/ipykernel_15517/53993724.py:3: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   srn.catplot(
